# %% [markdown]
# <a href="https://colab.research.google.com/github/Mangeldh529/PROBABILIDADYESTADISTICA/blob/main/Copia_de_Practica4_y_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ![image.png](data:image/png;base64,...)
#
# probabilidad y estadistica
# :Unidad 1
#  practica 4. Tabla de frecuencias y regla de Sturge
#
# Miguel Angel Diaz Herrera
#
#  José Gabriel Rodríguez Rivas

# %%
import random
edades=[]
for i in range(100):
  numero_aleatorio=random.randint(18, 70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [26, 58, 70, 26, 31, 26, 39, 60, 47, 26, 49, 54, 57, 43, 37, 50, 41, 36, 36, 33, 51, 64, 58, 37, 58, 68, 19, 52, 36, 40, 62, 30, 67, 28, 39, 27, 23, 36, 29, 18, 61, 67, 46, 26, 38, 47, 64, 55, 70, 29, 43, 44, 52, 21, 35, 43, 40, 51, 49, 42, 19, 32, 43, 39, 47, 54, 36, 55, 58, 23, 43, 53, 48, 64, 36, 58, 21, 51, 49, 62, 43, 21, 20, 54, 24, 66, 66, 52, 69, 50, 25, 26, 49, 46, 35, 62, 28, 64, 66, 46]

# %%
import pandas as pd

# %%
df=pd.DataFrame(edades,columns=['Edades'])
df.head()
# Out:
#    Edades
# 0      26
# 1      58
# 2      70
# 3      26
# 4      31

# %%
tabla_frecuencias=df['Edades'].value_counts().reset_index()
tabla_frecuencias.columns=['Edades','Frecuencia']
tabla_frecuencias=tabla_frecuencias.sort_values(by='Edades')
tabla_frecuencias
# Out:
#     Edades  Frecuencia
# 37      18           1
# 24      19           2
# 33      20           1
# 8       21           3
# 18      23           2
# 31      24           1
# 45      25           1
# 0       26           6
# 38      27           1
# 19      28           2
# 17      29           2
# 34      30           1
# 44      31           1
# 27      32           1
# 40      33           1
# 16      35           2
# 1       36           6
# 23      37           2
# 35      38           1
# 13      39           3
# 22      40           2
# 41      41           1
# 30      42           1
# 2       43           6
# 29      44           1
# 9       46           3
# 6       47           3
# 32      48           1
# 4       49           4
# 25      50           2
# 7       51           3
# 12      52           3
# 28      53           1
# 14      54           3
# 21      55           2
# 42      57           1
# 3       58           5
# 43      60           1
# 36      61           1
# ...

# %%
tabla_frecuencias['Frec Relativa']=tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edades  Frecuencia  Frec Relativa
# 37      18           1           0.01
# 24      19           2           0.02
# 33      20           1           0.01
# 8       21           3           0.03
# 18      23           2           0.02
# 31      24           1           0.01
# 45      25           1           0.01
# 0       26           6           0.06
# 38      27           1           0.01
# 19      28           2           0.02
# 17      29           2           0.02
# 34      30           1           0.01
# 44      31           1           0.01
# 27      32           1           0.01
# 40      33           1           0.01
# 16      35           2           0.02
# 1       36           6           0.06
# 23      37           2           0.02
# 35      38           1           0.01
# 13      39           3           0.03
# 22      40           2           0.02
# 41      41           1           0.01
# 30      42           1           0.01
# 2       43           6           0.06
# ...

# %%
tabla_frecuencias['Frec Porcentual']=tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edades  Frecuencia  Frec Relativa  Frec Porcentual
# 37      18           1           0.01              1.0
# 24      19           2           0.02              2.0
# 33      20           1           0.01              1.0
# 8       21           3           0.03              3.0
# 18      23           2           0.02              2.0
# 31      24           1           0.01              1.0
# 45      25           1           0.01              1.0
# 0       26           6           0.06              6.0
# 38      27           1           0.01              1.0
# 19      28           2           0.02              2.0
# 17      29           2           0.02              2.0
# 34      30           1           0.01              1.0
# 44      31           1           0.01              1.0
# 27      32           1           0.01              1.0
# 40      33           1           0.01              1.0
# 16      35           2           0.02              2.0
# ...

# %%
tabla_frecuencias['Frec Acumulada']=tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edades  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 37      18           1           0.01              1.0               1
# 24      19           2           0.02              2.0               3
# 33      20           1           0.01              1.0               4
# 8       21           3           0.03              3.0               7
# 18      23           2           0.02              2.0               9
# 31      24           1           0.01              1.0              10
# 45      25           1           0.01              1.0              11
# 0       26           6           0.06              6.0              17
# 38      27           1           0.01              1.0              18
# 19      28           2           0.02              2.0              20
# 17      29           2           0.02              2.0              22
# 34      30           1           0.01              1.0              23
# ...

# %% [markdown]
# Regla de sturge

# %%
import math

# %%
print(edades)
# Out:
# [26, 58, 70, 26, 31, 26, 39, 60, 47, 26, 49, 54, 57, 43, 37, 50, 41, 36, 36, 33, 51, 64, 58, 37, 58, 68, 19, 52, 36, 40, 62, 30, 67, 28, 39, 27, 23, 36, 29, 18, 61, 67, 46, 26, 38, 47, 64, 55, 70, 29, 43, 44, 52, 21, 35, 43, 40, 51, 49, 42, 19, 32, 43, 39, 47, 54, 36, 55, 58, 23, 43, 53, 48, 64, 36, 58, 21, 51, 49, 62, 43, 21, 20, 54, 24, 66, 66, 52, 69, 50, 25, 26, 49, 46, 35, 62, 28, 64, 66, 46]

# %%
df=pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     26
# 1     58
# 2     70
# 3     26
# 4     31
# ..   ...
# 95    62
# 96    28
# 97    64
# 98    66
# 99    46
#
# [100 rows x 1 columns]

# %%
n=len(edades)
k=int(1+math.log2(100))
print("valor de n:",n,"\nNumero de intervalos:",k )
# Out:
# valor de n: 100
# Numero de intervalos: 7

# %%
tabla_frecuencias=pd.cut(df['Edad'],bins=k,include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns=['Clase','Frec']
tabla_frecuencias
# Out:
#               Clase  Frec
# 0  (47.714, 55.143]    19
# 1  (32.857, 40.286]    17
# 2  (40.286, 47.714]    15
# 3  (25.429, 32.857]    14
# 4    (62.571, 70.0]    13
# 5  (17.947, 25.429]    11
# 6  (55.143, 62.571]    11

# %%
tabla_frecuencias=tabla_frecuencias.sort_values(by='Clase')
tabla_frecuencias
# Out:
#               Clase  Frec
# 5  (17.947, 25.429]    11
# 3  (25.429, 32.857]    14
# 1  (32.857, 40.286]    17
# 2  (40.286, 47.714]    15
# 0  (47.714, 55.143]    19
# 6  (55.143, 62.571]    11
# 4    (62.571, 70.0]    13

# %%
tabla_frecuencias['Frec Rel']=tabla_frecuencias['Frec']/n
tabla_frecuencias['Frec Por']=tabla_frecuencias['Frec']/n*100
tabla_frecuencias['Frec Ac']=tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['Frec Rel Ac']=tabla_frecuencias['Frec Rel'].cumsum()
tabla_frecuencias['frec por Ac']=tabla_frecuencias['Frec Por'].cumsum()
print(tabla_frecuencias)
# Out:
#               Clase  Frec  Frec Rel  Frec Por  Frec Ac  Frec Rel Ac  \
# 5  (17.947, 25.429]    11      0.11      11.0       11         0.11
# 3  (25.429, 32.857]    14      0.14      14.0       25         0.25
# 1  (32.857, 40.286]    17      0.17      17.0       42         0.42
# 2  (40.286, 47.714]    15      0.15      15.0       57         0.57
# 0  (47.714, 55.143]    19      0.19      19.0       76         0.76
# 6  (55.143, 62.571]    11      0.11      11.0       87         0.87
# 4    (62.571, 70.0]    13      0.13      13.0      100         1.00
#
#    frec por Ac
# 5         11.0
# 3         25.0
# 1         42.0
# 2         57.0
# 0         76.0
# 6         87.0
# 4        100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades,alpha=0.5)
plt.title('Histograma de edades')
# Out:
# Text(0.5, 1.0, 'Histograma de edades')

# %%
plt.hist(df['Edad'],bins=k,alpha=0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
#  ![image.png](data:image/png;base64,...)
#
# probabilidad y estadistica
# :Unidad 1
#  practica 5. Diagramas de Cajas y bigotes.
#
# Miguel Angel Diaz Herrerra
#
#  José Gabriel Rodríguez Rivas

# %%
import random
edades2=[]
for i in range(100):
  numero_aleatorio2=random.randint(20, 87)
  edades2.append(numero_aleatorio2)
print(edades2)
# Out:
# [61, 36, 33, 86, 23, 76, 21, 82, 30, 74, 86, 45, 22, 36, 37, 39, 44, 22, 30, 54, 52, 33, 23, 32, 40, 81, 42, 61, 32, 54, 75, 81, 80, 25, 55, 26, 39, 54, 53, 83, 36, 41, 31, 61, 55, 61, 79, 74, 59, 78, 78, 86, 25, 31, 68, 87, 73, 45, 51, 42, 37, 37, 55, 32, 45, 40, 44, 55, 57, 65, 74, 45, 87, 68, 83, 20, 65, 53, 74, 53, 38, 42, 30, 39, 37, 63, 47, 29, 57, 27, 42, 57, 68, 87, 60, 70, 70, 23, 78, 77]

# %%
fig,(ax1, ax2)=plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1=ax1.boxplot(edades,
                   vert=True,
                   patch_artist=True)
ax1.set_title('Edades encuesta 1')
bplot2=ax2.boxplot(edades2,
                   vert=True,
                   patch_artist=True)
ax2.set_title('Edades encuesta 2')
plt.show()

# %%
edades2.append(130)

# %%
fig,(ax1, ax2)=plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1=ax1.boxplot(edades,
                   vert=True,
                   patch_artist=True)
ax1.set_title('Edades encuesta 1')
bplot2=ax2.boxplot(edades2,
                   vert=True,
                   patch_artist=True)
ax2.set_title('Edades encuesta 2')
plt.show()
