# %% [markdown]
# <a href="https://colab.research.google.com/github/Mangeldh529/PROBABILIDADYESTADISTICA/blob/main/Practica1_y_2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# probabilidad y estadistica:
# Unidad 1.
#
# Practica 1 y 2. Estadística descriptiva básica e Histogramas
#
# Miguel Angel Diaz Herrera
#
#  José Gabriel Rodríguez Rivas

# %%
from statistics import *
grupoa=[70,70,65,90,100,95,45,80,73,20,100,96]
print (grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
type(grupoa)
# Out:
# list

# %%
promedio= sum(grupoa)/len(grupoa)
print (promedio)
# Out:
# 75.33333333333333

# %%
promedio2=mean(grupoa)
print (promedio2)
# Out:
# 75.33333333333333

# %%
mediana=median(grupoa)
print (mediana)
# Out:
# 76.5

# %%
moda=mode(grupoa)
print (moda)
# Out:
# 70

# %%
moda2=multimode(grupoa)
print (moda2)
# Out:
# [70, 100]

# %% [markdown]
# Ejemplo 2: Tiempos de 100 metros de 12 alumnos

# %%
tiempos100mts=[15.10,17.20,14.69,13.27,22.15,18.71,19.15,20.65,15.1,17.2]
print(tiempos100mts)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
print("El tiempo promedio de los corredores es →" , mean(tiempos100mts))
# Out:
# El tiempo promedio de los corredores es → 17.322

# %%
mediana=median(tiempos100mts)
print ("La media de tiempo de los corredores es →",mediana)
# Out:
# La media de tiempo de los corredores es → 17.2

# %%
moda=mode(tiempos100mts)
print ("La moda de tiempo de los corredores es →",moda)
# Out:
# La moda de tiempo de los corredores es → 15.1

# %%
multimodas=multimode(tiempos100mts)
print ("Las modas de tiempo de los corredores son →",multimodas)
# Out:
# Las modas de tiempo de los corredores son → [15.1, 17.2]

# %% [markdown]
# Ejemplo 3:Histograma de 2 grupos

# %%
import random

# %%
fabrica1=[]
for i in range(100):
 numero_aleatorio = round(random.uniform(50,100),2)
 fabrica1.append(numero_aleatorio)
print (fabrica1)
# Out:
# [52.62, 77.96, 97.31, 94.66, 66.6, 77.66, 90.56, 56.14, 80.09, 78.37, 91.88, 83.54, 99.36, 86.62, 98.01, 94.71, 80.08, 96.06, 96.08, 72.21, 69.84, 83.31, 71.32, 56.14, 93.09, 97.39, 54.38, 66.72, 88.23, 66.78, 91.88, 82.8, 62.5, 75.77, 72.41, 67.23, 97.54, 59.19, 78.6, 55.42, 51.82, 68.22, 69.5, 81.39, 70.25, 98.77, 71.95, 78.45, 69.78, 95.26, 79.05, 94.8, 66.88, 50.5, 59.63, 69.03, 76.0, 58.78, 99.65, 59.36, 73.86, 96.85, 54.43, 91.3, 55.2, 77.55, 76.43, 59.41, 79.9, 70.04, 50.51, 62.27, 54.58, 60.73, 82.34, 97.42, 84.01, 65.1, 98.2, 50.6, 60.05, 50.6, 51.32, 59.83, 87.15, 74.74, 62.07, 86.24, 76.71, 82.85, 98.41, 98.62, 98.29, 72.18, 52.51, 98.99, 90.9, 68.81, 62.4, 59.18]

# %%
fabrica2=[]
for i in range(100):
 numero_aleatorio2 = round(random.uniform(50,100),2)
 fabrica2.append(numero_aleatorio2)
print (fabrica2)
# Out:
# [62.42, 59.09, 86.99, 96.74, 84.48, 72.58, 54.07, 63.87, 67.61, 78.88, 97.59, 97.52, 67.46, 64.84, 89.86, 61.85, 50.75, 61.11, 99.07, 90.36, 77.86, 56.92, 96.77, 69.25, 73.47, 82.09, 91.11, 72.15, 87.41, 63.4, 84.83, 69.3, 80.29, 90.9, 69.8, 96.4, 78.22, 65.32, 76.48, 55.73, 97.84, 83.25, 77.25, 70.78, 66.55, 50.23, 98.46, 68.19, 54.66, 90.51, 85.64, 80.17, 85.7, 99.35, 69.91, 76.03, 63.51, 73.87, 74.29, 77.18, 65.99, 73.51, 61.98, 73.92, 59.88, 68.49, 97.36, 50.38, 59.97, 55.35, 80.97, 81.85, 86.94, 76.54, 74.76, 85.16, 64.45, 85.37, 50.33, 95.1, 80.0, 64.53, 73.34, 60.35, 59.81, 51.34, 87.92, 96.14, 62.26, 56.86, 93.65, 63.82, 83.53, 78.25, 71.78, 99.64, 91.05, 92.76, 52.16, 96.3]

# %%
import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("Produccion de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion de la fabrica 2')

# %%
media1=mean(fabrica1)
mediana1=median(fabrica1)
mod1=mode(fabrica1)

print("Valores Fabrica1")
print("Media:",media1)
print("Mediana:",mediana1)
print("Moda:",mod1)
# Out:
# Valores Fabrica1
# Media: 75.6271
# Mediana: 75.88499999999999
# Moda: 56.14

# %%
media2=mean(fabrica2)
mediana2=median(fabrica2)
mod2=mode(fabrica2)

print("Valores Fabrica2")
print("Media:",media2)
print("Mediana:",mediana2)
print("Moda:",mod2)
# Out:
# Valores Fabrica2
# Media: 75.52
# Mediana: 74.525
# Moda: 62.42

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2,figsize=(9,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(mod1, color='y', linestyle='dashed', linewidth=2, label= 'Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(mod2, color='y', linestyle='dashed', linewidth=2, label= 'Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()
